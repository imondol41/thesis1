# %%
from ultralytics import YOLO
import os, time, csv, glob
import torch
import gc

# ================== CONFIG ==================
data_yaml = r"F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\images\data_fixed.yaml"
epochs = 50                      # Full training
output_dir = "results_yolo"
detect_dir = os.path.join(output_dir, "detections")
os.makedirs(output_dir, exist_ok=True)
os.makedirs(detect_dir, exist_ok=True)

# All YOLO models
families = ["v8", "v10", "v11"]
variants = ["n", "s", "m", "l", "x"]

csv_path = os.path.join(output_dir, "yolo_train_eval_results.csv")

# ================== CHECK COMPLETED MODELS ==================
completed_models = set()
if os.path.exists(csv_path):
    try:
        import pandas as pd
        df = pd.read_csv(csv_path)
        completed_models = set(df[df['mAP50'] != 'ERROR']['Model'].tolist())
        print(f"✅ Found {len(completed_models)} completed models: {completed_models}")
    except:
        pass
else:
    # Initialize CSV if doesn't exist
    with open(csv_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Model", "mAP50", "mAP50-95", "Precision", "Recall", "Accuracy", "FPS", "TrainTime(s)", "ValTime(s)"])

# ================== RESUME YOLO10X FROM CHECKPOINT ==================
print("\n" + "=" * 60)
print("? RESUMING TRAINING - Starting from interrupted model")
print("=" * 60)

# Check if yolo10x has a checkpoint to resume from
yolo10x_checkpoint = os.path.join(output_dir, "yolov10x", "weights", "last.pt")
if os.path.exists(yolo10x_checkpoint) and "yolov10x" not in completed_models:
    print(f"\n{'='*60}")
    print(f"🔄 RESUMING yolov10x from epoch 23 checkpoint")
    print(f"{'='*60}")
    
    try:
        torch.cuda.empty_cache()
        gc.collect()
        
        model = YOLO(yolo10x_checkpoint)  # Load from checkpoint
        start_train = time.time()
        
        print(f"📊 Resuming from checkpoint: {yolo10x_checkpoint}")
        print(f"📊 Batch: 4, Image: 512x512")
        
        model.train(
            data=data_yaml,
            epochs=epochs,        # Will continue from epoch 23 to 50
            imgsz=512,
            device=0,
            project=output_dir,
            name="yolov10x",
            batch=4,
            exist_ok=True,
            cache=False,
            workers=0,
            amp=True,
            plots=False,
            save_period=5,        # Save checkpoint every 5 epochs
            val=True,
            verbose=True,
            patience=20,
            resume=True           # RESUME from checkpoint!
        )
        train_time = time.time() - start_train

        # Validate
        print(f"\n🔍 Evaluating yolov10x...")
        start_val = time.time()
        metrics = model.val(data=data_yaml, imgsz=512, split="val", device=0, save=False)
        val_time = time.time() - start_val

        mAP50 = metrics.box.map50
        mAP5095 = metrics.box.map
        precision = metrics.box.mp
        recall = metrics.box.mr
        fps = 1000 / metrics.speed["inference"] if metrics.speed and "inference" in metrics.speed else 0

        TP = recall * 100
        FP = (1 - precision) * 100
        FN = (1 - recall) * 100
        TN = 100 - (TP + FP + FN)
        accuracy = max(0, min(1, (TP + TN) / 100))

        print(f"✅ yolov10x | mAP50={mAP50:.3f} | Acc={accuracy:.3f} | FPS={fps:.1f}")

        # Save to CSV
        with open(csv_path, "a", newline="") as f:
            writer = csv.writer(f)
            writer.writerow(["yolov10x", mAP50, mAP5095, precision, recall, accuracy, fps, train_time, val_time])
        
        completed_models.add("yolov10x")
        print(f"🎉 yolov10x COMPLETE!")
        
    except Exception as e:
        print(f"❌ ERROR resuming yolov10x: {str(e)}")
        import traceback
        traceback.print_exc()
    
    finally:
        try:
            del model
        except:
            pass
        torch.cuda.empty_cache()
        gc.collect()

# ================== CONTINUE WITH REMAINING MODELS ==================
print(f"\n{'='*60}")
print(f"🚀 CONTINUING WITH REMAINING YOLO11 MODELS")
print(f"{'='*60}")

for family in families:
    for variant in variants:
        model_name = f"yolo{family}{variant}"
        
        # Skip already completed models
        if model_name in completed_models:
            print(f"\n⏩ Skipping {model_name} (already completed)")
            continue
        
        # Skip models before yolo10x (already done)
        if family == "v8" or (family == "v10" and variant != "x"):
            print(f"\n⏩ Skipping {model_name} (already trained)")
            continue
        
        weights = f"{model_name}.pt"

        print(f"\n{'='*60}")
        print(f"Training {model_name} for {epochs} epochs")
        print(f"{'='*60}")
        
        torch.cuda.empty_cache()
        gc.collect()
        
        model = YOLO(weights)
        start_train = time.time()
        
        # Batch size settings
        if variant in ["x", "l"]:
            batch_size = 4
            img_size = 512
        elif variant == "m":
            batch_size = 8
            img_size = 640
        else:
            batch_size = 16
            img_size = 640
        
        print(f"📊 Batch: {batch_size}, Image: {img_size}x{img_size}")
        
        try:
            model.train(
                data=data_yaml,
                epochs=epochs,
                imgsz=img_size,
                device=0,
                project=output_dir,
                name=model_name,
                batch=batch_size,
                exist_ok=True,
                cache=False,
                workers=0,
                amp=True,
                plots=False,
                save_period=5,     # Save checkpoint every 5 epochs
                val=True,
                verbose=True,
                patience=20
            )
            train_time = time.time() - start_train

            # Validate
            print(f"\n🔍 Evaluating {model_name}...")
            start_val = time.time()
            metrics = model.val(data=data_yaml, imgsz=img_size, split="val", device=0, save=False)
            val_time = time.time() - start_val

            mAP50 = metrics.box.map50
            mAP5095 = metrics.box.map
            precision = metrics.box.mp
            recall = metrics.box.mr
            fps = 1000 / metrics.speed["inference"] if metrics.speed and "inference" in metrics.speed else 0

            TP = recall * 100
            FP = (1 - precision) * 100
            FN = (1 - recall) * 100
            TN = 100 - (TP + FP + FN)
            accuracy = max(0, min(1, (TP + TN) / 100))

            print(f"✅ {model_name} | mAP50={mAP50:.3f} | Acc={accuracy:.3f} | FPS={fps:.1f}")

            # Save to CSV
            with open(csv_path, "a", newline="") as f:
                writer = csv.writer(f)
                writer.writerow([model_name, mAP50, mAP5095, precision, recall, accuracy, fps, train_time, val_time])
            
            print(f"🎉 {model_name} COMPLETE!")
            
        except Exception as e:
            print(f"❌ ERROR training {model_name}: {str(e)}")
            import traceback
            traceback.print_exc()
            
            with open(csv_path, "a", newline="") as f:
                writer = csv.writer(f)
                writer.writerow([model_name, "ERROR", "ERROR", "ERROR", "ERROR", "ERROR", "ERROR", 0, 0])
        
        finally:
            try:
                del model
            except:
                pass
            torch.cuda.empty_cache()
            gc.collect()
            
            if torch.cuda.is_available():
                mem_alloc = torch.cuda.memory_allocated(0) / 1024**3
                mem_reserved = torch.cuda.memory_reserved(0) / 1024**3
                print(f"🧹 GPU Memory: {mem_alloc:.2f}GB allocated, {mem_reserved:.2f}GB reserved\n")

# ================== FINAL SUMMARY ==================
print("\n" + "=" * 60)
print("ALL TRAINING COMPLETE!")
print("=" * 60)
print(f"📄 Results CSV: {csv_path}")
print(f"📦 Model Weights: {output_dir}/*/weights/best.pt")

print("\n📊 RESULTS SUMMARY:")
try:
    import pandas as pd
    df = pd.read_csv(csv_path)
    df_clean = df[df['mAP50'] != 'ERROR'].copy()
    df_clean['mAP50'] = pd.to_numeric(df_clean['mAP50'])
    print(df_clean.to_string(index=False))
    
    if len(df_clean) > 0:
        best_idx = df_clean['mAP50'].idxmax()
        best_model = df_clean.loc[best_idx, 'Model']
        best_map = df_clean.loc[best_idx, 'mAP50']
        print(f"\n🏆 BEST MODEL: {best_model} with mAP50 = {best_map:.3f}")
        
        print(f"\n📈 PROGRESS: {len(df_clean)}/15 models completed ({len(df_clean)/15*100:.1f}%)")
except Exception as e:
    print(f"Error displaying results: {e}")

# %%
from ultralytics import YOLO
import os, time, csv
import torch
import gc
from pathlib import Path

# ================== TRAIN ALL 15 YOLO MODELS ==================
print("=" * 60)
print("🚀 Training ALL 15 YOLO Models (v8, v10, v11)")
print("=" * 60)

data_yaml = r"F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\images\data_fixed.yaml"
epochs = 50
output_dir = "results_yolo"
csv_path = os.path.join(output_dir, "yolo_train_eval_results.csv")

# Base directory for model weights (same directory as notebook)
weights_dir = r"F:\skills-copilot-codespaces-vscode\thesis\all code\weights"

# ALL 15 YOLO models to train
all_models = []
for family in ["v8", "v10", "v11"]:
    for variant in ["n", "s", "m", "l", "x"]:
        all_models.append(f"yolo{family}{variant}")

print(f"📋 Total models to train: {len(all_models)}")
print(f"   Models: {', '.join(all_models)}")

# ================== CHECK COMPLETED MODELS ==================
completed_models = set()
if os.path.exists(csv_path):
    try:
        import pandas as pd
        df = pd.read_csv(csv_path)
        completed_models = set(df[df['mAP50'] != 'ERROR']['Model'].tolist())
        print(f"\n✅ Found {len(completed_models)} completed models: {completed_models}")
    except Exception as e:
        print(f"⚠️ Could not read CSV (may be open in Excel): {e}")
else:
    # Initialize CSV if doesn't exist
    print(f"\n📝 Creating new CSV file...")
    os.makedirs(output_dir, exist_ok=True)
    with open(csv_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Model", "mAP50", "mAP50-95", "Precision", "Recall", "Accuracy", "FPS", "TrainTime(s)", "ValTime(s)"])

# Calculate remaining models
remaining_models = [m for m in all_models if m not in completed_models]
print(f"\n📊 Progress: {len(completed_models)}/{len(all_models)} completed, {len(remaining_models)} remaining")
if remaining_models:
    print(f"   Remaining: {', '.join(remaining_models)}")

print(f"\n⚡ Starting training loop...\n")

# ================== TRAIN EACH MODEL ==================
for idx, model_name in enumerate(all_models, 1):
    # Skip if already completed
    if model_name in completed_models:
        print(f"\n[{idx}/{len(all_models)}] ⏩ Skipping {model_name} - already completed!")
        continue
    
    print(f"\n{'='*60}")
    print(f"[{idx}/{len(all_models)}] 🚀 Training {model_name}")
    print(f"{'='*60}")
    
    torch.cuda.empty_cache()
    gc.collect()
    
    # Check for checkpoint
    checkpoint = os.path.join(output_dir, model_name, "weights", "last.pt")
    resume = False
    
    if os.path.exists(checkpoint):
        # Check if checkpoint is finished
        try:
            ckpt = torch.load(checkpoint, map_location='cpu')
            last_epoch = ckpt.get('epoch', -1)
            if last_epoch >= epochs - 1:
                print(f"✅ {model_name} already trained to {last_epoch + 1} epochs")
                
                # Run validation to get metrics
                print(f"🔍 Running validation to record metrics...")
                model = YOLO(os.path.join(output_dir, model_name, "weights", "best.pt"))
                
                img_size = 640
                
                start_val = time.time()
                metrics = model.val(data=data_yaml, imgsz=img_size, split="val", device=0, save=False)
                val_time = time.time() - start_val
                
                mAP50 = metrics.box.map50
                mAP5095 = metrics.box.map
                precision = metrics.box.mp
                recall = metrics.box.mr
                fps = 1000 / metrics.speed["inference"] if metrics.speed and "inference" in metrics.speed else 0
                
                TP = recall * 100
                FP = (1 - precision) * 100
                FN = (1 - recall) * 100
                TN = 100 - (TP + FP + FN)
                accuracy = max(0, min(1, (TP + TN) / 100))
                
                print(f"✅ {model_name}: mAP50={mAP50:.4f}, Acc={accuracy:.4f}")
                
                # Save to CSV
                for attempt in range(3):
                    try:
                        with open(csv_path, "a", newline="") as f:
                            writer = csv.writer(f)
                            writer.writerow([model_name, mAP50, mAP5095, precision, recall, accuracy, fps, 0, val_time])
                        print(f"📝 Results saved to CSV")
                        break
                    except PermissionError:
                        if attempt < 2:
                            print(f"⚠️ CSV locked. Retrying in 5 seconds...")
                            time.sleep(5)
                        else:
                            print(f"Results: {model_name},{mAP50},{mAP5095},{precision},{recall},{accuracy},{fps},0,{val_time}")
                
                completed_models.add(model_name)
                del model
                torch.cuda.empty_cache()
                gc.collect()
                continue
            else:
                print(f"📂 RESUMING from checkpoint: epoch {last_epoch + 1}/{epochs}")
                model = YOLO(checkpoint)
                resume = True
        except Exception as e:
            print(f"⚠️ Could not check checkpoint: {e}")
            print(f"🆕 STARTING FRESH")
            
            # Try both naming conventions for v11: yolov11n.pt and yolo11n.pt
            weights_path = os.path.join(weights_dir, f"{model_name}.pt")
            if not os.path.exists(weights_path) and "v11" in model_name:
                # Try without 'v' for YOLOv11 models
                alt_name = model_name.replace("yolov11", "yolo11")
                weights_path = os.path.join(weights_dir, f"{alt_name}.pt")
                print(f"🔍 Trying alternate name: {alt_name}.pt")
            
            if os.path.exists(weights_path):
                print(f"✅ Found local weights: {weights_path}")
                model = YOLO(weights_path)
            else:
                print(f"❌ Weights not found: {weights_path}")
                print(f"❌ Skipping {model_name}")
                continue
    else:
        print(f"🆕 STARTING FRESH")
        
        # Try both naming conventions for v11: yolov11n.pt and yolo11n.pt
        weights_path = os.path.join(weights_dir, f"{model_name}.pt")
        if not os.path.exists(weights_path) and "v11" in model_name:
            # Try without 'v' for YOLOv11 models
            alt_name = model_name.replace("yolov11", "yolo11")
            weights_path = os.path.join(weights_dir, f"{alt_name}.pt")
            print(f"🔍 Trying alternate name: {alt_name}.pt")
        
        if os.path.exists(weights_path):
            print(f"✅ Found local weights: {weights_path}")
            model = YOLO(weights_path)
        else:
            print(f"❌ Weights not found: {weights_path}")
            print(f"❌ Skipping {model_name}")
            continue
    
    start_train = time.time()
    
    # Optimized batch sizes for 10GB GPU
    if "x" in model_name:
        batch_size = 6
        img_size = 640
    elif "l" in model_name:
        batch_size = 10
        img_size = 640
    elif "m" in model_name:
        batch_size = 16
        img_size = 640
    elif "s" in model_name:
        batch_size = 24
        img_size = 640
    else:  # nano
        batch_size = 32
        img_size = 640
    
    print(f"📊 Settings: Batch={batch_size}, Image={img_size}, Cache=False, Workers=2")
    
    try:
        print(f"⏳ Starting training...")
        
        result = model.train(
            data=data_yaml,
            epochs=epochs,
            imgsz=img_size,
            device=0,
            project=output_dir,
            name=model_name,
            batch=batch_size,
            exist_ok=True,
            cache=False,
            workers=2,
            amp=True,
            plots=False,
            save_period=5,
            val=True,
            verbose=True,
            patience=20,
            resume=resume,
            close_mosaic=10
        )
        train_time = time.time() - start_train
        
        # Validate
        print(f"\n🔍 Evaluating {model_name}...")
        start_val = time.time()
        metrics = model.val(data=data_yaml, imgsz=img_size, split="val", device=0, save=False)
        val_time = time.time() - start_val
        
        mAP50 = metrics.box.map50
        mAP5095 = metrics.box.map
        precision = metrics.box.mp
        recall = metrics.box.mr
        fps = 1000 / metrics.speed["inference"] if metrics.speed and "inference" in metrics.speed else 0
        
        TP = recall * 100
        FP = (1 - precision) * 100
        FN = (1 - recall) * 100
        TN = 100 - (TP + FP + FN)
        accuracy = max(0, min(1, (TP + TN) / 100))
        
        print(f"\n✅ {model_name}: mAP50={mAP50:.4f}, Acc={accuracy:.4f}, Time={train_time/3600:.2f}h")
        
        # Save to CSV with retry logic
        max_retries = 3
        for attempt in range(max_retries):
            try:
                with open(csv_path, "a", newline="") as f:
                    writer = csv.writer(f)
                    writer.writerow([model_name, mAP50, mAP5095, precision, recall, accuracy, fps, train_time, val_time])
                print(f"📝 Results saved to CSV")
                break
            except PermissionError:
                if attempt < max_retries - 1:
                    print(f"⚠️ CSV file locked (close Excel?). Retrying in 5 seconds... ({attempt+1}/{max_retries})")
                    time.sleep(5)
                else:
                    print(f"❌ Could not save to CSV after {max_retries} attempts. Results:")
                    print(f"   {model_name},{mAP50},{mAP5095},{precision},{recall},{accuracy},{fps},{train_time},{val_time}")
        
        completed_models.add(model_name)
        print(f"🎉 {model_name} COMPLETE! ({len(completed_models)}/{len(all_models)})")
        
    except RuntimeError as e:
        if "out of memory" in str(e).lower():
            print(f"\n❌ OOM with batch={batch_size}. Retrying with batch={batch_size//2}...")
            torch.cuda.empty_cache()
            gc.collect()
            
            try:
                result = model.train(
                    data=data_yaml, epochs=epochs, imgsz=img_size, device=0,
                    project=output_dir, name=model_name, batch=batch_size//2,
                    exist_ok=True, cache=False, workers=2, amp=True,
                    plots=False, save_period=5, val=True, resume=resume
                )
                train_time = time.time() - start_train
                metrics = model.val(data=data_yaml, imgsz=img_size, split="val", device=0, save=False)
                
                mAP50 = metrics.box.map50
                mAP5095 = metrics.box.map
                precision = metrics.box.mp
                recall = metrics.box.mr
                fps = 1000 / metrics.speed["inference"] if metrics.speed and "inference" in metrics.speed else 0
                TP = recall * 100
                FP = (1 - precision) * 100
                FN = (1 - recall) * 100
                TN = 100 - (TP + FP + FN)
                accuracy = max(0, min(1, (TP + TN) / 100))
                
                for attempt in range(3):
                    try:
                        with open(csv_path, "a", newline="") as f:
                            writer = csv.writer(f)
                            writer.writerow([model_name, mAP50, mAP5095, precision, recall, accuracy, fps, train_time, val_time])
                        break
                    except PermissionError:
                        if attempt < 2:
                            time.sleep(5)
                        else:
                            print(f"Results: {model_name},{mAP50},{mAP5095},{precision},{recall},{accuracy},{fps},{train_time},{val_time}")
                
                print(f"✅ Retry succeeded!")
                completed_models.add(model_name)
            except Exception as e2:
                print(f"❌ Retry failed: {e2}")
                try:
                    with open(csv_path, "a", newline="") as f:
                        writer = csv.writer(f)
                        writer.writerow([model_name, "ERROR", "ERROR", "ERROR", "ERROR", "ERROR", "ERROR", 0, 0])
                except PermissionError:
                    print(f"Results: {model_name},ERROR,ERROR,ERROR,ERROR,ERROR,ERROR,0,0")
        else:
            print(f"❌ ERROR: {e}")
            try:
                with open(csv_path, "a", newline="") as f:
                    writer = csv.writer(f)
                    writer.writerow([model_name, "ERROR", "ERROR", "ERROR", "ERROR", "ERROR", "ERROR", 0, 0])
            except PermissionError:
                print(f"Results: {model_name},ERROR,ERROR,ERROR,ERROR,ERROR,ERROR,0,0")
    
    except Exception as e:
        print(f"❌ ERROR: {e}")
        import traceback
        traceback.print_exc()
        try:
            with open(csv_path, "a", newline="") as f:
                writer = csv.writer(f)
                writer.writerow([model_name, "ERROR", "ERROR", "ERROR", "ERROR", "ERROR", "ERROR", 0, 0])
        except PermissionError:
            print(f"⚠️ Could not write to CSV (file may be open)")
            print(f"Results: {model_name},ERROR,ERROR,ERROR,ERROR,ERROR,ERROR,0,0")
    
    finally:
        try:
            del model
        except:
            pass
        torch.cuda.empty_cache()
        gc.collect()
        
        if torch.cuda.is_available():
            mem = torch.cuda.memory_allocated(0) / 1024**3
            print(f"🧹 GPU Memory: {mem:.2f}GB\n")

# ================== FINAL SUMMARY ==================
print("\n" + "=" * 60)
print(f"🏁 ALL {len(all_models)} MODELS TRAINING COMPLETE!")
print("=" * 60)

# Show summary
try:
    import pandas as pd
    df = pd.read_csv(csv_path)
    df_clean = df[df['mAP50'] != 'ERROR'].copy()
    df_clean['mAP50'] = pd.to_numeric(df_clean['mAP50'])
    
    print(f"\n📊 FINAL RESULTS ({len(df_clean)}/{len(all_models)} successful):")
    print(df_clean.to_string(index=False))
    
    if len(df_clean) > 0:
        best_idx = df_clean['mAP50'].idxmax()
        print(f"\n🏆 BEST MODEL: {df_clean.loc[best_idx, 'Model']} - mAP50={df_clean.loc[best_idx, 'mAP50']:.4f}")
        
        # Show top 5
        print(f"\n🥇 TOP 5 MODELS:")
        top5 = df_clean.nlargest(5, 'mAP50')[['Model', 'mAP50', 'Accuracy', 'FPS']]
        for i, row in top5.iterrows():
            model_str = str(row['Model'])
            map_val = float(row['mAP50'])
            acc_val = float(row['Accuracy'])
            fps_val = float(row['FPS'])
            print(f"   {model_str:12} - mAP50: {map_val:.4f}, Acc: {acc_val:.4f}, FPS: {fps_val:.1f}")
    
    # Show any errors
    df_errors = df[df['mAP50'] == 'ERROR']
    if len(df_errors) > 0:
        print(f"\n⚠️ Models with errors: {', '.join(df_errors['Model'].tolist())}")
    
except PermissionError:
    print("⚠️ CSV file is locked (close Excel to view results)")
except Exception as e:
    print(f"⚠️ Could not display results: {e}")

print(f"\n📄 Results saved to: {csv_path}")
print(f"📦 Model weights: {output_dir}/*/weights/best.pt")
# Out:
# ============================================================
# 🚀 Training ALL 15 YOLO Models (v8, v10, v11)
# ============================================================
# 📋 Total models to train: 15
#    Models: yolov8n, yolov8s, yolov8m, yolov8l, yolov8x, yolov10n, yolov10s, yolov10m, yolov10l, yolov10x, yolov11n, yolov11s, yolov11m, yolov11l, yolov11x
#
# ✅ Found 10 completed models: {'yolov8x', 'yolov8n', 'yolov10x', 'yolov10s', 'yolov8s', 'yolov10m', 'yolov8l', 'yolov8m', 'yolov10n', 'yolov10l'}
#
# 📊 Progress: 10/15 completed, 5 remaining
#    Remaining: yolov11n, yolov11s, yolov11m, yolov11l, yolov11x
#
# ⚡ Starting training loop...
#
#
# [1/15] ⏩ Skipping yolov8n - already completed!
#
# [2/15] ⏩ Skipping yolov8s - already completed!
#
# [3/15] ⏩ Skipping yolov8m - already completed!
#
# [4/15] ⏩ Skipping yolov8l - already completed!
#
# [5/15] ⏩ Skipping yolov8x - already completed!
#
# [6/15] ⏩ Skipping yolov10n - already completed!
#
# [7/15] ⏩ Skipping yolov10s - already completed!
#
# [8/15] ⏩ Skipping yolov10m - already completed!
#
# [9/15] ⏩ Skipping yolov10l - already completed!
#
# [10/15] ⏩ Skipping yolov10x - already completed!
#
# ============================================================
# [11/15] 🚀 Training yolov11n
# ============================================================
# 🆕 STARTING FRESH
# 🔍 Trying alternate name: yolo11n.pt
# ✅ Found local weights: F:\skills-copilot-codespaces-vscode\thesis\all code\weights\yolo11n.pt
# 📊 Settings: Batch=10, Image=640, Cache=False, Workers=2
# ⏳ Starting training...
# New https://pypi.org/project/ultralytics/8.3.228 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.225  Python-3.13.9 torch-2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# New https://pypi.org/project/ultralytics/8.3.228 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.225  Python-3.13.9 torch-2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=10, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\images\data_fixed.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=F:\skills-copilot-codespaces-vscode\thesis\all code\weights\yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov11n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=False, pose=12.0, pretrained=True, profile=False, project=results_yolo, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=F:\skills-copilot-codespaces-vscode\thesis\all code\weights\results_yolo\yolov11n, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=10, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\images\data_fixed.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=F:\skills-copilot-codespaces-vscode\thesis\all code\weights\yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov11n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=False, pose=12.0, pretrained=True, profile=False, project=results_yolo, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=F:\skills-copilot-codespaces-vscode\thesis\all code\weights\results_yolo\yolov11n, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=13
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
# Overriding model.yaml nc=80 with nc=13
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    433207  ultralytics.nn.modules.head.Detect           [13, [64, 128, 256]]
#  23        [16, 19, 22]  1    433207  ultralytics.nn.modules.head.Detect           [13, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,592,375 parameters, 2,592,359 gradients, 6.5 GFLOPs
#
# YOLO11n summary: 181 layers, 2,592,375 parameters, 2,592,359 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 1832.71187.2 MB/s, size: 529.4 KB)
# train: Fast image access  (ping: 0.00.0 ms, read: 1832.71187.2 MB/s, size: 529.4 KB)
# train: Scanning F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\labels\train.cache... 18681 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 18681/18681 27.4Mit/s 0.0s
# train: Scanning F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\labels\train.cache... 18681 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 18681/18681 27.4Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.00.0 ms, read: 1932.21186.8 MB/s, size: 467.3 KB)
# val: Fast image access  (ping: 0.00.0 ms, read: 1932.21186.8 MB/s, size: 467.3 KB)
# val: Scanning F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\labels\val.cache... 1004 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1004/1004 884.1Kit/s 0.0s
# val: Scanning F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\labels\val.cache... 1004 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1004/1004 884.1Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.00046875), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to F:\skills-copilot-codespaces-vscode\thesis\all code\weights\results_yolo\yolov11n
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.00046875), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to F:\skills-copilot-codespaces-vscode\thesis\all code\weights\results_yolo\yolov11n
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      1.52G      1.167      1.902      1.093         19        640: 100% ━━━━━━━━━━━━ 1869/1869 3.2it/s 9:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 0.8it/s 1:03<0.4ss
#                    all       1004       7385      0.546      0.484      0.523      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      1.53G      1.083      1.182      1.057         27        640: 100% ━━━━━━━━━━━━ 1869/1869 6.0it/s 5:10<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 1.0it/s 49.9s0.2s
#                    all       1004       7385      0.628      0.488      0.547      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      1.54G      1.103      1.123       1.07          5        640: 100% ━━━━━━━━━━━━ 1869/1869 6.3it/s 4:57<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 7.2it/s 7.1s0.1s
#                    all       1004       7385      0.595       0.48      0.523      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      1.54G      1.113      1.064      1.076         16        640: 100% ━━━━━━━━━━━━ 1869/1869 6.1it/s 5:04<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 1.5it/s 34.8s0.2s
#                    all       1004       7385      0.638      0.499       0.57      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      1.54G      1.067     0.9468       1.05         25        640: 100% ━━━━━━━━━━━━ 1869/1869 6.1it/s 5:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 3.9it/s 13.2s0.2s
#                    all       1004       7385      0.647      0.521      0.594      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      1.61G      1.032       0.88      1.032          9        640: 100% ━━━━━━━━━━━━ 1869/1869 6.1it/s 5:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 1.9it/s 26.4s0.2s
#                    all       1004       7385      0.621      0.553      0.596      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      1.61G      1.001     0.8313      1.019          6        640: 100% ━━━━━━━━━━━━ 1869/1869 6.2it/s 5:02<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 4.1it/s 12
2Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 7.4it/s 8.5s0.1s
#                    all       1004       7385      0.734      0.646      0.723      0.573
#                 person        566       1917      0.849      0.693      0.827      0.578
#               rickshaw        648       1587      0.854      0.799      0.883      0.722
#           rickshaw_van        160        240      0.623      0.668      0.663      0.404
#          auto_rickshaw        388        590      0.824      0.853      0.912      0.769
#                  truck         62         65      0.681      0.585      0.617      0.533
#           pickup_truck         66         74      0.658      0.595      0.689      0.524
#            private_car        776       1420      0.853      0.791      0.883       0.73
#             motorcycle        550        860       0.84      0.765      0.858      0.632
#                bicycle        135        146      0.675      0.418      0.516      0.353
#                    bus        169        182      0.825      0.676      0.794      0.648
#              micro_bus        215        241      0.674       0.61      0.684      0.621
#            covered_van         38         40      0.606      0.422      0.534      0.452
#           human_hauler         22         23      0.585      0.522      0.544      0.479
# Speed: 0.9ms preprocess, 2.3ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to F:\skills-copilot-codespaces-vscode\thesis\all code\weights\runs\detect\val12
#
# ✅ yolov11n: mAP50=0.7234, Acc=0.3802, Time=4.33h
# 📝 Results saved to CSV
# 🎉 yolov11n COMPLETE! (11/15)
# 🧹 GPU Memory: 0.06GB
#
#
# ============================================================
# [12/15] 🚀 Training yolov11s
# ============================================================
# 🆕 STARTING FRESH
# 🔍 Trying alternate name: yolo11s.pt
# ✅ Found local weights: F:\skills-copilot-codespaces-vscode\thesis\all code\weights\yolo11s.pt
# 📊 Settings: Batch=10, Image=640, Cache=False, Workers=2
# ⏳ Starting training...
# New https://pypi.org/project/ultralytics/8.3.228 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.225  Python-3.13.9 torch-2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=10, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\images\data_fixed.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=F:\skills-copilot-codespaces-vscode\thesis\all code\weights\yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov11s, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=False, pose=12.0, pretrained=True, profile=False, project=results_yolo, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=F:\skills-copilot-codespaces-vscode\thesis\all code\weights\results_yolo\yolov11s, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=13
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    824439  ultralytics.nn.modules.head.Detect           [13, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,432,823 parameters, 9,432,807 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 1809.9723.7 MB/s, size: 497.4 KB)
# train: Scanning F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\labels\train.cache... 18681 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 18681/18681 16.1Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.10.0 ms, read: 33.524.5 MB/s, size: 480.1 KB)
# val: Scanning F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\labels\val.cache... 1004 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1004/1004 662.3Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.00046875), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to F:\skills-copilot-codespaces-vscode\thesis\all code\weights\results_yolo\yolov11s
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.62G      1.003      1.097      1.002         19        640: 100% ━━━━━━━━━━━━ 1869/1869 5.3it/s 5:53<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 5.1it/s 10.0s.2s
#                    all       1004       7385      0.686      0.622      0.694       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.62G      0.945     0.7657     0.9783         27        640: 100% ━━━━━━━━━━━━ 1869/1869 5.8it/s 5:21<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 6.8it/s 7.5s0.2s
#                    all       1004       7385      0.722      0.584      0.675      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.64G     0.9837        0.8     0.9975          5        640: 100% ━━━━━━━━━━━━ 1869/1869 5.8it/s 5:21<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 6.1it/s 8.4s0.2s
#                    all       1004       7385      0.709      0.535      0.619      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.64G       1.01     0.8201      1.013         16        640: 100% ━━━━━━━━━━━━ 1869/1869 6.0it/s 5:13<0.1s
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50       6.8G     0.6392     0.4019     0.9215         34        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 21:06<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.9s0.2s
#                    all       1004       7385      0.848      0.705       0.82      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      6.79G     0.6342     0.3989     0.9204         51        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 21:03<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.9s0.2s
#                    all       1004       7385       0.83      0.704      0.812      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      6.73G       0.63     0.3932     0.9202         39        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 21:01<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.8s0.2s
#                    all       1004       7385      0.817       0.71       0.81      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      6.75G     0.6219     0.3894      0.916         41        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.8s0.2s
#                    all       1004       7385      0.854      0.689      0.818      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      6.71G     0.6161     0.3831     0.9131         25        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.7s0.2s
#                    all       1004       7385      0.804      0.723      0.816      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      6.58G     0.6092     0.3791     0.9111         42        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.7s0.2s
#                    all       1004       7385      0.817      0.718      0.815      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      6.57G     0.6026      0.374     0.9093         42        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.8s0.2s
#                    all       1004       7385      0.825      0.717      0.814      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      6.73G     0.5976     0.3676     0.9073         14        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.9s0.2s
#                    all       1004       7385      0.832      0.713      0.815      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      6.58G     0.5956     0.3631      0.906         50        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 21:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.8s0.2s
#                    all       1004       7385        0.8      0.737      0.817      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      6.65G     0.5884     0.3571     0.9043         33        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.7s0.2s
#                    all       1004       7385      0.814      0.725      0.817      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      6.83G     0.5843     0.3548     0.9021         39        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.9s0.2s
#                    all       1004       7385      0.824      0.717      0.816      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      6.79G     0.5799     0.3506     0.8985         34        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.9s0.2s
#                    all       1004       7385      0.845      0.696      0.814      0.671
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      6.77G     0.5625     0.3218     0.8797         19        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:55<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.8s0.2s
#                    all       1004       7385      0.809      0.717       0.81      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      6.36G     0.5536     0.3139     0.8759         19        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:53<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.7s0.2s
#                    all       1004       7385      0.805      0.713      0.806      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      6.35G     0.5458     0.3083     0.8748         11        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:55<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.8s0.2s
#                    all       1004       7385      0.789      0.723      0.804      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      6.35G     0.5388     0.3032     0.8702         25        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:55<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.7s0.2s
#                    all       1004       7385      0.806      0.704      0.802      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      6.34G     0.5315     0.2967     0.8681         23        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:55<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.7s0.2s
#                    all       1004       7385      0.797      0.708      0.799      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      6.32G      0.527     0.2928     0.8692         28        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:55<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.7s0.2s
#                    all       1004       7385      0.794      0.711      0.798      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      6.54G     0.5191     0.2865     0.8633         21        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.9s0.2s
#                    all       1004       7385      0.791      0.716      0.797      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      6.35G     0.5121     0.2827     0.8638         18        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:60<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 4.9it/s 17.1s0.2s
#                    all       1004       7385      0.794       0.71      0.796       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      6.63G     0.5048     0.2765     0.8637         16        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.8s0.2s
#                    all       1004       7385      0.797      0.708      0.794      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      6.82G     0.5014     0.2718     0.8618         24        640: 100% ━━━━━━━━━━━━ 3114/3114 2.5it/s 20:55<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.0it/s 16.7s0.2s
#                    all       1004       7385      0.814      0.695      0.794      0.658
#
# 50 epochs completed in 17.931 hours.
# Optimizer stripped from F:\skills-copilot-codespaces-vscode\thesis\all code\weights\results_yolo\yolov11x\weights\last.pt, 114.4MB
# Optimizer stripped from F:\skills-copilot-codespaces-vscode\thesis\all code\weights\results_yolo\yolov11x\weights\best.pt, 114.4MB
#
# Validating F:\skills-copilot-codespaces-vscode\thesis\all code\weights\results_yolo\yolov11x\weights\best.pt...
# Ultralytics 8.3.225  Python-3.13.9 torch-2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# YOLO11x summary (fused): 190 layers, 56,842,039 parameters, 0 gradients, 194.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 84/84 5.9it/s 14.1s0.2s
#                    all       1004       7385      0.854      0.689      0.819      0.674
#                 person        566       1917        0.9      0.772      0.902      0.675
#               rickshaw        648       1587      0.897      0.819      0.928      0.787
#           rickshaw_van        160        240        0.8      0.633      0.782       0.51
#          auto_rickshaw        388        590      0.952      0.851      0.952      0.831
#                  truck         62         65      0.775      0.582      0.754      0.639
#           pickup_truck         66         74      0.865      0.676      0.761      0.603
#            private_car        776       1420      0.905      0.791      0.918      0.798
#             motorcycle        550        860      0.927      0.813       0.92      0.713
#                bicycle        135        146      0.786      0.582      0.728      0.546
#                    bus        169        182      0.882      0.701      0.861      0.736
#              micro_bus        215        241      0.729      0.664      0.748      0.688
#            covered_van         38         40      0.806       0.45      0.643      0.559
#           human_hauler         22         23      0.877      0.623      0.743      0.675
# Speed: 0.1ms preprocess, 10.9ms inference, 0.0ms loss, 1.1ms postprocess per image
#
# 🔍 Evaluating yolov11x...
# Ultralytics 8.3.225  Python-3.13.9 torch-2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# YOLO11x summary (fused): 190 layers, 56,842,039 parameters, 0 gradients, 194.5 GFLOPs
# val: Fast image access  (ping: 3.78.3 ms, read: 20.210.3 MB/s, size: 541.5 KB)
# val: Scanning F:\skills-copilot-codespaces-vscode\thesis\rsuddataset\rsud20k\labels\val.cache... 1004 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1004/1004 1.4Mit/s 0.0s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 2.6it/s 24.6s0.4ss
#                    all       1004       7385      0.854      0.689      0.818      0.675
#                 person        566       1917      0.901      0.772      0.902      0.677
#               rickshaw        648       1587      0.896      0.819      0.928      0.788
#           rickshaw_van        160        240        0.8      0.633      0.781      0.509
#          auto_rickshaw        388        590      0.952      0.851       0.95      0.833
#                  truck         62         65      0.775      0.582      0.754      0.641
#           pickup_truck         66         74      0.866      0.676      0.761      0.605
#            private_car        776       1420      0.906      0.791      0.918      0.799
#             motorcycle        550        860      0.927      0.813       0.92      0.714
#                bicycle        135        146      0.786      0.582      0.728      0.546
#                    bus        169        182      0.882      0.701      0.862      0.737
#              micro_bus        215        241      0.729      0.664      0.748      0.689
#            covered_van         38         40      0.806       0.45      0.643       0.56
#           human_hauler         22         23      0.877      0.623      0.743      0.678
# Speed: 0.9ms preprocess, 19.3ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to F:\skills-copilot-codespaces-vscode\thesis\all code\weights\runs\detect\val16
#
# ✅ yolov11x: mAP50=0.8185, Acc=0.5429, Time=17.94h
# 📝 Results saved to CSV
# 🎉 yolov11x COMPLETE! (15/15)
# 🧹 GPU Memory: 0.06GB
#
#
# ============================================================
# 🏁 ALL 15 MODELS TRAINING COMPLETE!
# ============================================================
#
# 📊 FINAL RESULTS (15/15 successful):
#    Model    mAP50  mAP50-95  Precision   Recall  Accuracy        FPS  TrainTime(s)  ValTime(s)
#  yolov8n 0.745403  0.586793   0.752534 0.657094  0.409628 417.810878  28016.659670   35.750391
#  yolov8s 0.793226  0.644757   0.798932 0.706000  0.504932 275.356999  34892.752900   37.967808
#  yolov8m 0.811114  0.667096   0.791344 0.735046  0.526389 121.696275  53869.015510   38.954074
#  yolov8l 0.803367  0.657068   0.831576 0.693985  0.525562 101.641725  56345.950320   41.832022
#  yolov8x 0.804395  0.656591   0.824346 0.703247  0.527593  64.589049  71352.844040   48.871514
# yolov10n 0.718173  0.570745   0.799541 0.601999  0.401540 308.608486  31967.255350   35.726100
# yolov10s 0.761848  0.625362   0.794219 0.673606  0.467825 266.918676  40535.930640   35.100209
# yolov10m 0.802754  0.661615   0.843645 0.697120  0.540766 133.190049  61754.755680   39.156023
# yolov10l 0.807666  0.658530   0.855691 0.707401  0.563092 114.288941  80779.746640   41.733222
# yolov10x 0.812326  0.674143   0.854575 0.685881  0.540456  53.281140   5482.087407   45.458626
# yolov11n 0.723422  0.572777   0.734441 0.645803  0.380244 432.093160  15587.385460   31.238900
# yolov11s 0.784035  0.638752   0.800401 0.693344  0.493746 269.926824  16677.712750   31.925559
# yolov11m 0.810664  0.663843   0.823652 0.712885  0.536538 127.666393  29259.299360   35.102512
# yolov11l 0.808598  0.668264   0.827326 0.701806  0.529132  98.458476  37229.149240   37.473570
# yolov11x 0.818472  0.675257   0.854092 0.688825  0.542917  51.788805  64590.478759   46.638674
#
# 🏆 BEST MODEL: yolov11x - mAP50=0.8185
#
# 🥇 TOP 5 MODELS:
#    yolov11x     - mAP50: 0.8185, Acc: 0.5429, FPS: 51.8
#    yolov10x     - mAP50: 0.8123, Acc: 0.5405, FPS: 53.3
#    yolov8m      - mAP50: 0.8111, Acc: 0.5264, FPS: 121.7
#    yolov11m     - mAP50: 0.8107, Acc: 0.5365, FPS: 127.7
#    yolov11l     - mAP50: 0.8086, Acc: 0.5291, FPS: 98.5
#
# 📄 Results saved to: results_yolo\yolo_train_eval_results.csv
# 📦 Model weights: results_yolo/*/weights/best.pt
